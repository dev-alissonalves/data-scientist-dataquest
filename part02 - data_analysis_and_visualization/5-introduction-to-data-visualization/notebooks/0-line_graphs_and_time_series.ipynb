# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Qual é o comprimento unitário do eixo x? Atribua sua resposta a x_unit_length.
# 2. Qual é o comprimento unitário do eixo y? Atribua sua resposta a y_unit_length.
# 3. Qual é a coordenada x do ponto A? Atribua sua resposta a x_coordinate_A.
# 4. Qual é a coordenada y do ponto B? Atribua sua resposta a y_coordinate_B.
# 5. Quais são as coordenadas x e y do ponto C? Atribua sua resposta como lista C_coordinates- a coordenada x deve vir primeiro na sua lista.

# %%
# Introduction

x_unit_length = 10
y_unit_length = 1000
x_coordinate_A = 70
y_coordinate_B = 5000
C_coordinates = [50, 9000]

# %%
# Line Graphs

sentence_1 = True
sentence_2 = False
sentence_3 = True
sentence_4 = True

# %%
# Matplotlib

import matplotlib.pyplot as plt
month_number = [1, 2, 3, 4, 5, 6, 7]
new_cases = [9926, 76246, 681488, 2336640,
             2835147, 4226655, 6942042]
plt.plot(month_number, new_cases)
plt.show()

# %%
# Matplotlib (Continued)

month_number = [1, 2, 3, 4, 5, 6, 7]
new_deaths = [213, 2729, 37718, 184064, 143119, 136073, 165003]

plt.plot(month_number, new_deaths)
plt.show()

# %%
# Customizing a Graph

plt.title('New Reported Cases by Month — Globally')
plt.xlabel('Month Number')
plt.ylabel('Number Of Cases')
plt.plot(month_number, new_cases)
plt.ticklabel_format(axis='y', style='plain')
plt.show()

# %%
# Customizing a Graph

import matplotlib.pyplot as plt

plt.title('New Reported Deaths By Month (Globally)')
plt.xlabel('Month Number')
plt.ylabel('Number Of Deaths')

month_number = [1, 2, 3, 4, 5, 6, 7]
new_deaths = [213, 2729, 37718, 184064, 143119, 136073, 165003]
plt.plot(month_number, new_deaths)
plt.show()

# %%
# WHO Time Series Data
import pandas as pd
who_time_series = pd.read_csv('../dataset/WHO_time_series.csv')
who_time_series.head()

who_time_series['Date_reported'] = pd.to_datetime(who_time_series['Date_reported'])

print(who_time_series.head(5))
print(who_time_series.tail(5))
print(who_time_series.info())

# %%
# Types of Growth
